# %%
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"D:\Linkedin\job-hunt-415021-00446b9fe5c6.json"
os.environ['GEMINI_API_KEY'] = "AIzaSyAp-wL4lTTIMFJg1NpFJZRtvXb1rXgOYZ8"
os.environ['LINKEDIN_EMAIL'] = "sawlanimohnish@gmail.com"
os.environ['LINKEDIN_PASSWORD'] = "LinkdinpasMonu**"

# %%
from linkedinBot.bot import LinkedInBot
bot = LinkedInBot(headless=False,resume_path=r"D:\Linkedin\resume.pdf")
bot.login()
bot.start_applying()
# %run linkedinBot/utils/gsheet.py
bot.populate_connections()
bot.close()
# %run linkedinBot/utils/gsheet.py
# Out:
# Logging in to LinkedIn...
# Starting the search for Financial analyst
# Total jobs available for 'Financial analyst': 920
# Processing page 1 for position 'Financial analyst'
# Found 25 jobs on this page
#   4%|▍         | 1/25 [00:04<01:50,  4.62s/it]
# Employee count '11-50 employees' is not acceptable.
# Using model: gemini-2.5-pro
# Rate limit reached for gemini-2.5-pro, switching to next model...
# Using model: gemini-2.5-flash
#   8%|▊         | 2/25 [00:23<05:03, 13.18s/it]
# Job description does not match resume.
# Using model: gemini-2.5-pro
# Rate limit reached for gemini-2.5-pro, switching to next model...
# Using model: gemini-2.5-flash
#  12%|█▏        | 3/25 [00:41<05:37, 15.32s/it]
# Job description does not match resume.
# Employee count not found.
# Using model: gemini-2.5-pro
# Rate limit reached for gemini-2.5-pro, switching to next model...
# Using model: gemini-2.5-flash
#  16%|█▌        | 4/25 [01:07<06:44, 19.28s/it]
# Job description does not match resume.
# ...
